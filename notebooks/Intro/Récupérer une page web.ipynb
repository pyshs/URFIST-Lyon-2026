# %% [markdown]
# # Récupérer une page web

# %%
url = "https://urfist.univ-lyon1.fr/"

# %% [markdown]
# ## Méthode 1: urllib

# %%
from urllib.request import urlopen
with urlopen(url) as response:
    body = response.read()

# %%
# body.decode()

# %% [markdown]
# ## Méthode 2

# %%
pip install -U requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
requests.__version__
# Out:
# '2.32.5'

# %%
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
type(r)
# Out:
# requests.models.Response

# %%
with open("page.html","w") as f:
    f.write(r.text)

# %%
html = r.text

# %%
len(html)
# Out:
# 56307

# %%
html_min = html.lower()
html_min.count("science ouverte")
# Out:
# 1

# %%
html_min.count("open science")
# Out:
# 0
