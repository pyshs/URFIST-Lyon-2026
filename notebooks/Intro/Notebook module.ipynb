# %%
import module

# %%
module.proportion_mots_seuil("Ceci est mon texte")
# Out:
# {'Total': 2, 'Proportion': 50.0, 'Phrase': 'Ceci est mon texte', 'Seuil': 4}

# %%
import math

# %%
math
# Out:
# <module 'math' from '/opt/anaconda3/lib/python3.11/lib-dynload/math.cpython-311-darwin.so'>

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.log10?
# Out:
# Signature: math.log10(x, /)
# Docstring: Return the base 10 logarithm of x.
# Type:      builtin_function_or_method

# %%
from math import log10

# %%
log10(100)
# Out:
# 2.0

# %%
pip install pyshs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
