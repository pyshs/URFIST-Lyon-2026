# %% [markdown]
# # Collecter des données OpenAlex

# %% [markdown]
# ## Découvrir l'API

# %% [markdown]
# Jeter un coup d'oeil ici : https://docs.openalex.org/how-to-use-the-api/api-overview

# %% [markdown]
# Il faut un token

# %%
import yaml
with open('creds.yaml', 'r') as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# https://openalex.org/works?page=1&filter=title_and_abstract.search:%22computational+social+science%22

# %%
import requests

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

params = {
    "q": "computational social science",
    "per-page": 25,
    "page": 1,
}

r = requests.get(url, headers=headers, params=params)
r.raise_for_status()
data = r.json()
#print(data["results"])

# %% [markdown]
# Get all the data

# %%
import requests
import time


keyword = "computational social science"
per_page = 25     
max_results = None 

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

cursor = "*"
all_works = []
n = 0

while True:
    params = {
        "filter": f'title_and_abstract.search:"{keyword}"',
        "per-page": per_page,
        "select": "id,title,abstract_inverted_index,publication_year,publication_date,open_access,relevance_score",
        "cursor": cursor
    }

    r = requests.get(url, headers=headers, params=params)
    r.raise_for_status()
    data = r.json()

    results = data.get("results", [])
    total = data["meta"]["count"]

    if not results:
        break

    all_works.extend(results)
    n += len(results)

    print(f"Fetched {n} / {total} (cursor={cursor})")

    if max_results is not None and n >= max_results:
        break

    cursor = data["meta"].get("next_cursor")
    if not cursor:
        break

    time.sleep(0.2)

print(f"\nDone. Collected {len(all_works)} works total.\n")
# Out:
# Fetched 25 / 2102 (cursor=*)
# Fetched 50 / 2102 (cursor=IlsxOTIuODc5NzUsIDE2MDMyMzg0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDQyMzA2OCddIg==)
# Fetched 75 / 2102 (cursor=IlsxMjYuMjMwODYsIDE0MjU5NDU2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwMzc2MTkyMCddIg==)
# Fetched 100 / 2102 (cursor=Ils5OC45ODY4MiwgMTM4ODUzNDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNDg2NDU0NTg4J10i)
# Fetched 125 / 2102 (cursor=Ils4MS43NzA4NywgMTY3NDc3NzYwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MzE4MjQ1MzQ3J10i)
# Fetched 150 / 2102 (cursor=Ils2Ny4xNzEyOSwgMTY1NDgxOTIwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MjgyODI0Mjc0J10i)
# Fetched 175 / 2102 (cursor=Ils1Ny42MzM1MzMsIDE2NzI1MzEyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDMxNzc3MjI1MiddIg==)
# Fetched 200 / 2102 (cursor=Ils1MS42NDg5NiwgMTYwNjUyMTYwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1czMTA2NjkyMzIyJ10i)
# Fetched 225 / 2102 (cursor=Ils0NS4yNjA0OCwgMTY2MTk5MDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzc5NDEwNzc3J10i)
# Fetched 250 / 2102 (cursor=Ils0Mi4wNTAyLCAxNTA4MzcxMjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI4MDc5NjQ3MjUnXSI=)
# Fetched 275 / 2102 (cursor=IlszNy42NjI0NjQsIDE2ODg1MTUyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NjIxNDgyMiddIg==)
# Fetched 300 / 2102 (cursor=IlszMC4xNjMxMjYsIDE3NTg1ODU2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQxNDQzNzQzNSddIg==)
# Fetched 325 / 2102 (cursor=IlsxOC42ODk5MzYsIDEyNjc0MDE2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE0MDk0ODQzNiddIg==)
# Fetched 350 / 2102 (cursor=IlsxMS43MjU2OTUsIDEzODg1MzQ0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDIzOTczNTgyNSddIg==)
# Fetched 375 / 2102 (cursor=IlsxMC43OTkzMDgsIDE1MjkwMjA4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjgxMDQ2MzAyNyddIg==)
# Fetched 400 / 2102 (cursor=IlsxMC40NDE0MjEsIDE2MTQ5MDI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMz
IwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MzgzNzUzMTE2J10i)
# Fetched 1075 / 2102 (cursor=IlszLjAyNjU0MjcsIDE2MzY1MDI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxMjM3NDU0NCddIg==)
# Fetched 1100 / 2102 (cursor=IlsyLjkxMjYwMjQsIDE1Nzc4MzY4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyOTQ1NDEyNSddIg==)
# Fetched 1125 / 2102 (cursor=IlsyLjc5Nzg4NTIsIDE0OTIzODcyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjYwNTc2NTM0MyddIg==)
# Fetched 1150 / 2102 (cursor=IlsyLjY2MjQ4NDYsIDE2MDk0NTkyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE3OTY2NTg2MyddIg==)
# Fetched 1175 / 2102 (cursor=IlsyLjUxMTQxMjEsIDE0MDE1ODA4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTY2MDAwNTM0MyddIg==)
# Fetched 1200 / 2102 (cursor=IlsyLjQxODAyMSwgMTcxMTc1NjgwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzk0NTk5OTExJ10i)
# Fetched 1225 / 2102 (cursor=IlsyLjMxODM1NTgsIDE3MTQ2OTQ0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjYxNzE1NyddIg==)
# Fetched 1250 / 2102 (cursor=IlsyLjI0NDkxMywgMTU4MjE1NjgwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1czMDA3NTk4NDU4J10i)
# Fetched 1275 / 2102 (cursor=IlsyLjEyMTgxOTUsIDE3MzgwMjI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwNjkwOTU3OCddIg==)
# Fetched 1300 / 2102 (cursor=IlsyLjAxMjExNDUsIDE1NDQ0MDAwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NDU1NDg0MiddIg==)
# Fetched 1325 / 2102 (cursor=IlsxLjg2MjU0MzEsIDE1Nzc4MzY4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEwODk3NTQyMyddIg==)
# Fetched 1350 / 2102 (cursor=IlsxLjY5NTA4MjcsIDE2OTUzNDA4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NzgwNTgwNyddIg==)
# Fetched 1375 / 2102 (cursor=IlswLjk2NTY1MjgsIDE2MDQzNjE2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NTE2NDQyNCddIg==)
# Fetched 1400 / 2102 (cursor=IlswLjgzNjk4NzUsIDE2NDA5OTUyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyNjQyNjgwMiddIg==)
# Fetched 1425 / 2102 (cursor=IlswLjc1OTU1NzcsIDE3MDQwNjcyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMzU0OTM1NiddIg==)
# Fetched 1450 / 2102 (cursor=IlswLjcxMzg0OTY2LCAxNzY4ODY3MjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzcxMjQ5Mjk2NzUnXSI=)
# Fetched 1475 / 2102 (cursor=IlswLjY3MjM5NDA0LCAxNzIyNTU2ODAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDEyNzAzNzAnXSI=)
# Fetched 1500 / 2102 (cursor=IlswLjY0ODAzNjEsIDE1NzYxMDg4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEyODYwMDQ4NCddIg==)
# Fetched 1525 / 2102 (cursor=IlswLjYxODA0MzMsIDE1NDYzMDA4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDIzNTM1NDQ2OSddIg==)
# Fetched 1550 / 2102 (cursor=IlswLjYxNjQ2NDQsIDE3NzEzNzI4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzExNzY1MzA4MiddIg==)
# Fetched 1575 / 2102 (cursor=IlswLjU5ODAzNDgsIDE2OTU2ODY0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NzYwODY0NiddIg==)
# Fetched 1600 / 2102 (cursor=IlswLjU5NjYzNjgsIDE2OTE1MzkyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NTc1MDE3NyddIg==)
# Fetched 1625 / 2102 (cursor=IlswLjU3OTM1ODY0LCAxNzI0MTk4NDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDE3OTg4NzYnXSI=)
# Fetched 1650 / 2102 (cursor=IlswLjU3ODIxMjcsIDE3Mzc1MDQwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwNjc3OTQ1NiddIg==)
# Fetched 1675 / 2102 (cursor=IlswLjU2MjE5ODMsIDE3NTc1NDg4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQxNTA5MDQ1MCddIg==)
# Fetched 1700 / 2102 (cursor=IlswLjU0NjkwNjksIDE1MjYzNDI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyODg2ODI1MSddIg==)
# Fetched 1725 / 2102 (cursor=IlswLjU0NTc4Mjc0LCAxNzM1Njg5NjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MTQ3MTk5ODUnXSI=)
# Fetched 1750 / 2102 (cursor=IlswLjUzMTIwNDc2LCAxNzYyMzAwODAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzcxMDQwNDAzMzAnXSI=)
# Fetched 1775 / 2102 (cursor=IlswLjUzMDI3NzUsIDE3NDI5NDcyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQxMDA3NzgxNCddIg==)
# Fetched 1800 / 2102 (cursor=IlswLjUxNjMzNzIsIDE3Njc5MTY4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyNDExNzUyMSddIg==)
# Fetched 1825 / 2102 (cursor=IlswLjUxNTIzMjgsIDkyMjMzNzIwMzY4NTQ3NzU4MDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzExMTc0OTI5MiddIg==)
# Fetched 1850 / 2102 (cursor=IlswLjUwMjU0NjQsIDE3NjcyMjU2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyODA5MzY2NyddIg==)
# Fetched 1875 / 2102 (cursor=IlswLjUwMTc5OTA1LCAxNzU0ODcwNDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MTMyMjgwNzUnXSI=)
# Fetched 1900 / 2102 (cursor=IlswLjQ4OTQ1ODI2LCAxNTU0NjgxNjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5Mzc3NzQ4NTUnXSI=)
# Fetched 1925 / 2102 (cursor=IlswLjQ4ODU2NjM0LCAxNTE5Nzc2MDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMDA4Njg2NDcnXSI=)
# Fetched 1950 / 2102 (cursor=IlswLjQ2NTIyNjEsIDE3NDA3MDA4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzExMjI2NTU5MiddIg==)
# Fetched 1975 / 2102 (cursor=IlswLjQ2NDQ5MSwgMTc2NzM5ODQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c3MTI0MTE4MDUxJ10i)
# Fetched 2000 / 2102 (cursor=IlswLjQ0MzEyNDQsIDE3Njk5OTA0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyNzQ1Mjc0MiddIg==)
# Fetched 2025 / 2102 (cursor=IlswLjQyMzEzMzYsIDE3MzU2ODk2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEwNTk5ODUxOSddIg==)
# Fetched 2050 / 2102 (cursor=IlswLjM3Mzc3NjQ0LCAxNzcwMjQ5NjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzcxMjg3Mzg1NTInXSI=)
# Fetched 2075 / 2102 (cursor=IlswLjM0NTk0OTQsIDE2MzIwOTYwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIwNjAxNzc3MCddIg==)
# Fetched 2100 / 2102 (cursor=IlswLjI4NDExNTczLCAxNzI0MTk4NDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDE3NjY3NzInXSI=)
# Fetched 2124 / 2102 (cursor=IlswLjIwMDI5NzQ3LCAxNjY5ODUyODAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMTA1MTk4MzYnXSI=)
#
# Done. Collected 2124 works total.

# %% [markdown]
# Sauvegarder les données

# %%
import pickle
import os

os.makedirs("data", exist_ok=True)

with open("data/all_works.pkl", "wb") as f:
    pickle.dump(all_works, f)

# %% [markdown]
# ## Mettre sous la forme d'un dataframe

# %%
def reconstruct_abstract(inv_index):
    if not inv_index:
        return None
    
    # Determine abstract length
    max_position = max(pos for positions in inv_index.values() for pos in positions)
    abstract_words = [None] * (max_position + 1)

    # Place words in correct positions
    for word, positions in inv_index.items():
        for pos in positions:
            abstract_words[pos] = word

    return " ".join([i for i in abstract_words if i is not None])

# reconstruct_abstract(all_works[200]["abstract_inverted_index"])

# %%
import pandas as pd
df = pd.DataFrame(all_works)
df["abstract"] = df["abstract_inverted_index"].apply(reconstruct_abstract)
df.to_csv("data/css_openalex_26022026.csv", index=False)
