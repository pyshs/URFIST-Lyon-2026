# %% [markdown]
# # Collecter des données OpenAlex

# %% [markdown]
# ## Découvrir l'API

# %% [markdown]
# Jeter un coup d'oeil ici : https://docs.openalex.org/how-to-use-the-api/api-overview

# %% [markdown]
# Il faut un token

# %%
import yaml
with open('creds.yaml', 'r') as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# https://openalex.org/works?page=1&filter=title_and_abstract.search:%22computational+social+science%22

# %%
import requests

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

params = {
    "q": "computational social science",
    "per-page": 25,
    "page": 1,
}

r = requests.get(url, headers=headers, params=params)
data = r.json()
#print(data["results"])

# %% [markdown]
# Get all the data

# %%
import requests
import time


keyword = "computational social science"
per_page = 25     
max_results = None 

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

cursor = "*"
all_works = []
n = 0

while True:
    params = {
        "filter": f'title_and_abstract.search:"{keyword}"',
        "per-page": per_page,
        "select": "id,type,title,abstract_inverted_index,publication_year,publication_date,open_access,relevance_score",
        "cursor": cursor
    }

    r = requests.get(url, headers=headers, params=params)
    r.raise_for_status()
    data = r.json()

    results = data.get("results", [])
    total = data["meta"]["count"]

    if not results:
        break

    all_works.extend(results)
    n += len(results)

    print(f"Fetched {n} / {total} (cursor={cursor})")

    if max_results is not None and n >= max_results:
        break

    cursor = data["meta"].get("next_cursor")
    if not cursor:
        break

    time.sleep(0.2)

print(f"\nDone. Collected {len(all_works)} works total.\n")
# Out:
# Fetched 25 / 2138 (cursor=*)
# Fetched 50 / 2138 (cursor=IlsxOTYuNTY5ODksIDE2MDMyMzg0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDQyMzA2OCddIg==)
# Fetched 75 / 2138 (cursor=IlsxMjkuMDA0NjEsIDE0MjU5NDU2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwMzc2MTkyMCddIg==)
# Fetched 100 / 2138 (cursor=IlsxMDEuMDIxMzgsIDE1NTA0NDgwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkxNjkyMDIzOCddIg==)
# Fetched 125 / 2138 (cursor=Ils4My42NjI2OCwgMTY3NDc3NzYwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MzE4MjQ1MzQ3J10i)
# Fetched 150 / 2138 (cursor=Ils2OC4zMTI5NCwgMTY1NDgxOTIwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MjgyODI0Mjc0J10i)
# Fetched 175 / 2138 (cursor=Ils1OC40OTgyMDcsIDE2NzI1MzEyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDMxNzc3MjI1MiddIg==)
# Fetched 200 / 2138 (cursor=Ils1Mi41MzY2MywgMTcwNDA2NzIwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzk4MTk5MjExJ10i)
# Fetched 225 / 2138 (cursor=Ils0Ni4wODg3NzYsIDEzNDA1ODI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTExMzY0NTk2J10i)
# Fetched 250 / 2138 (cursor=Ils0Mi42NzQ2NywgMTcwNDA2NzIwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MzkwNzk0NDMwJ10i)
# Fetched 275 / 2138 (cursor=IlszOC40NjIwODYsIDEzMDY0NTQ0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwODUyNzM5OSddIg==)
# Fetched 300 / 2138 (cursor=IlszMC44ODI0NywgMTM1OTY3NjgwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNTM0OTQ3NzMxJ10i)
# Fetched 325 / 2138 (cursor=IlsxOC43OTMyMDMsIDEyNjc0MDE2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE0MDk0ODQzNiddIg==)
# Fetched 350 / 2138 (cursor=IlsxMS44MjU3MzIsIDE0NzA2MTQ0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2MzA3MTc0OSddIg==)
# Fetched 375 / 2138 (cursor=IlsxMC45Nzk3OTcsIDE2NDYwOTI4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEzMjQ4NDY1MCddIg==)
# Fetched 400 / 2138 (cursor=IlsxMC41OTM3NDMsIDE1MDc3NjY0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XM
#all_works[0]

# %% [markdown]
# ## Mettre sous la forme d'un dataframe

# %%
def reconstruct_abstract(inv_index):
    if not inv_index:
        return None
    
    # Determine abstract length
    max_position = max(pos for positions in inv_index.values() for pos in positions)
    abstract_words = [None] * (max_position + 1)

    # Place words in correct positions
    for word, positions in inv_index.items():
        for pos in positions:
            abstract_words[pos] = word

    return " ".join([i for i in abstract_words if i is not None])

#reconstruct_abstract(all_works[200]["abstract_inverted_index"])

# %%
import pandas as pd
df = pd.DataFrame(all_works)
df["abstract"] = df["abstract_inverted_index"].apply(reconstruct_abstract)
df.to_csv("data/css_openalex_26022026.csv", index=False)

# %%
df
# Out:
#                                     id  \
# 0     https://openalex.org/W2159397589
# 1     https://openalex.org/W2070907364
# 2     https://openalex.org/W3081158114
# 3     https://openalex.org/W3022499311
# 4     https://openalex.org/W3174174150
# ...                                ...
# 2148  https://openalex.org/W4413141860
# 2149  https://openalex.org/W4231832138
# 2150  https://openalex.org/W4405505218
# 2151  https://openalex.org/W4376626896
# 2152  https://openalex.org/W4376626896
#
#                                                   title  \
# 0                          Computational Social Science
# 1             Manifesto of computational social science
# 2     Computational social science: Obstacles and op...
# 3            Computational Social Science and Sociology
# 4     Integrating explanation and prediction in comp...
# ...                                                 ...
# 2148  AI-Driven Behavioral and Sociocultural Analysi...
# 2149                                              Index
# 2150  Publishing academic books in emerging fields: ...
# 2151                                              Index
# 2152                                              Index
#
#                                 abstract_inverted_index  publication_year  \
# 0     {'A': [0], 'field': [1], 'is': [2], 'emerging'...            2009.0
# 1                                                  None            2012.0
# 2     {'Data': [0], 'sharing,': [1], 'research': [2]...            2020.0
# 3     {'The': [0], 'integration': [1], 'of': [2, 16,...            2020.0
# 4                                                  None            2021.0
# ...                                                 ...               ...
# 2148  {'Author:': [0], 'Khan': [1], 'Tahsin': [2], '...            2025.0
# 2149  {'Citation': [0], '(2020),': [1], '"Index",': ...            2020.0
# 2150  {'Publishing': [0, 240, 261, 325, 561, 3442, 3...            2024.0
# 2151  {'Citation': [0], '(2023),': [1], '"Index",': ...            2023.0
# 2152  {'Citation': [0], '(2023),': [1], '"Index",': ...            2023.0
#
#      publication_date                                        open_access  \
# 0          2009-02-06  {'is_oa': True, 'oa_status': 'green', 'oa_url'...
# 1          2012-11-01  {'is_oa': True, 'oa_status': 'hybrid', 'oa_url...
# 2          2020-08-28  {'is_oa': True, 'oa_status': 'green', 'oa_url'...
# 3          2020-04-28  {'is_oa': True, 'oa_status': 'hybrid', 'oa_url...
# 4          2021-06-30  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...
# ...               ...                                                ...
# 2148       2025-08-11  {'is_oa': True, 'oa_status': 'gold', 'oa_url':...
# 2149       2020-10-06  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...
# 2150       2024-12-05  {'is_oa': True, 'oa_status': 'gold', 'oa_url':...
# 2151       2023-05-15  {'is_oa': True, 'oa_status': 'gold', 'oa_url':...
# 2152       2023-05-15  {'is_oa': True, 'oa_status': 'gold', 'oa_url':...
#
#       relevance_score                                           abstract
# 0         1384.055200  A field is emerging that leverages the capacit...
# 1          506.214630                                               None
# 2          447.696840  Data sharing, research ethics, and incentives ...
# 3          418.060900  The integration of social science with compute...
# 4          415.996500                                               None
# ...               ...                                                ...
# 2148         0.087551  Author: Khan Tahsin AbrarAffiliation: Independ...
# 2149         0.067181  Citation (2020), "Index", Härtel, C.E.J., Zerb...
# 2150         0.046386  Publishing academic books in emerging fields p...
# 2151         0.040249  Citation (2023), "Index", Lytras, M.D., Housaw...
# 2152         0.040215  Citation (2023), "Index", Lytras, M.D., Housaw...
#
# [2153 rows x 8 columns]
